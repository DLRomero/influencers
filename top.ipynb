# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable 

#  Modelado y evaluación
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.impute import KNNImputer
#  Crossvalidation
import regex as re
# ------------------------------------------------------------------------------
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics

# %%
tk= pd.read_csv('./Datos/tk_limpio.csv', index_col=0)
tk.head()
# Out:
#     Tiktoker name          Tiktok name    Followers  Views avg.  Likes avg  \
# 0        ekin.721               MOMO’s     221700.0  26000000.0  2800000.0
# 1         dojacat             Doja Cat   22200000.0  25400000.0  5000000.0
# 2     kiet.ac.quy           Kiệt Ắk Wỷ    2100000.0  20700000.0  3500000.0
# 3   charlidamelio      charli d’amelio  135400000.0  18700000.0  2600000.0
# 4  luvadepedreiro  Iran Ferreira (Lai)   11400000.0  24800000.0  2600000.0
#
#    Comments avg.  Shares avg red_social
# 0        29400.0    116400.0     TikTok
# 1        36700.0     46800.0     TikTok
# 2        38800.0     33900.0     TikTok
# 3        54700.0     35200.0     TikTok
# 4        32700.0     26800.0     TikTok

# %%
tk.sort_values(by='Followers', ascending=False, inplace=True)
tk.head()
# Out:
#     Tiktoker name      Tiktok name    Followers  Views avg.  Likes avg  \
# 3   charlidamelio  charli d’amelio  135400000.0  18700000.0  2600000.0
# 6      khaby.lame     Khabane lame  135200000.0  17700000.0  2300000.0
# 31    bellapoarch     Bella Poarch   88500000.0  11100000.0  1000000.0
# 27      addisonre      Addison Rae   87300000.0   9300000.0  1200000.0
# 63      willsmith       Will Smith   67400000.0   6900000.0   658500.0
#
#     Comments avg.  Shares avg red_social
# 3         54700.0     35200.0     TikTok
# 6         18000.0     11200.0     TikTok
# 31        14300.0      1600.0     TikTok
# 27        13400.0      5900.0     TikTok
# 63        10000.0      2000.0     TikTok

# %%
tk=tk[:10]
tk
# Out:
#        Tiktoker name      Tiktok name    Followers  Views avg.  Likes avg  \
# 3      charlidamelio  charli d’amelio  135400000.0  18700000.0  2600000.0
# 6         khaby.lame     Khabane lame  135200000.0  17700000.0  2300000.0
# 31       bellapoarch     Bella Poarch   88500000.0  11100000.0  1000000.0
# 27         addisonre      Addison Rae   87300000.0   9300000.0  1200000.0
# 63         willsmith       Will Smith   67400000.0   6900000.0   658500.0
# 22   kimberly.loaiza  Kimberly Loaiza   61000000.0   9900000.0  1300000.0
# 280     dixiedamelio            dixie   57200000.0   4400000.0   275200.0
# 844        lorengray       Loren Gray   54300000.0   1800000.0   248400.0
# 25          domelipa          Dominik   50700000.0   7900000.0  1200000.0
# 74        kallmekris          Kris HC   43300000.0   5400000.0   988000.0
#
#      Comments avg.  Shares avg red_social
# 3          54700.0     35200.0     TikTok
# 6          18000.0     11200.0     TikTok
# ...

# %%
tk= tk[['Tiktok name', 'Followers', 'red_social']]
tk
# Out:
#          Tiktok name    Followers red_social
# 3    charli d’amelio  135400000.0     TikTok
# 6       Khabane lame  135200000.0     TikTok
# 31      Bella Poarch   88500000.0     TikTok
# 27       Addison Rae   87300000.0     TikTok
# 63        Will Smith   67400000.0     TikTok
# 22   Kimberly Loaiza   61000000.0     TikTok
# 280            dixie   57200000.0     TikTok
# 844       Loren Gray   54300000.0     TikTok
# 25           Dominik   50700000.0     TikTok
# 74           Kris HC   43300000.0     TikTok

# %%
tk.rename(columns={'Followers': 'TikTok'}, inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/3014923054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tk.rename(columns={'Followers': 'TikTok'}, inplace=True)

# %%
tk.rename(columns={'Tiktok name': 'user'}, inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/3908220601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tk.rename(columns={'Tiktok name': 'user'}, inplace=True)

# %%
yt= pd.read_csv('./Datos/youtube_limpio.csv', index_col=0)
yt.head()
# Out:
#   youtuber name                channel name       Category       audience  \
# 0       tseries                    T-Series  Music & Dance          India
# 1     checkgate  Cocomelon - Nursery Rhymes      Education         Varios
# 2      setindia                   SET India             Tv          India
# 3     PewDiePie                   PewDiePie      Animation  United States
# 4   MrBeast6000                     MrBeast    Video games  United States
#
#      Followers   avg views  avg likes red_social
# 0  212100000.0    323700.0     9800.0    Youtube
# 1  132100000.0  13800000.0    80900.0    Youtube
# 2  130400000.0     23600.0      314.0    Youtube
# 3  111400000.0   1400000.0    80800.0    Youtube
# 4   92500000.0  30600000.0  1700000.0    Youtube

# %%
yt.sort_values(by='Followers', ascending=False, inplace=True)
yt.head()
# Out:
#   youtuber name                channel name       Category       audience  \
# 0       tseries                    T-Series  Music & Dance          India
# 1     checkgate  Cocomelon - Nursery Rhymes      Education         Varios
# 2      setindia                   SET India             Tv          India
# 3     PewDiePie                   PewDiePie      Animation  United States
# 4   MrBeast6000                     MrBeast    Video games  United States
#
#      Followers   avg views  avg likes red_social
# 0  212100000.0    323700.0     9800.0    Youtube
# 1  132100000.0  13800000.0    80900.0    Youtube
# 2  130400000.0     23600.0      314.0    Youtube
# 3  111400000.0   1400000.0    80800.0    Youtube
# 4   92500000.0  30600000.0  1700000.0    Youtube

# %%
yt=yt[:10]
yt
# Out:
#        youtuber name                channel name       Category  \
# 0            tseries                    T-Series  Music & Dance
# 1          checkgate  Cocomelon - Nursery Rhymes      Education
# 2           setindia                   SET India             Tv
# 3          PewDiePie                   PewDiePie      Animation
# 4        MrBeast6000                     MrBeast    Video games
# 5  ✿ Kids Diana Show           ✿ Kids Diana Show      Animation
# 6        Like Nastya                 Like Nastya      Animation
# 7       WWEFanNation                         WWE    Video games
# 8    zeemusiccompany           Zee Music Company  Music & Dance
# 9      Vlad and Niki               Vlad and Niki           Toys
#
#         audience    Followers   avg views  avg likes red_social
# 0          India  212100000.0    323700.0     9800.0    Youtube
# 1         Varios  132100000.0  13800000.0    80900.0    Youtube
# 2          India  130400000.0     23600.0      314.0    Youtube
# ...

# %%
yt=yt[['channel name', 'Followers', 'red_social']]
yt
# Out:
#                  channel name    Followers red_social
# 0                    T-Series  212100000.0    Youtube
# 1  Cocomelon - Nursery Rhymes  132100000.0    Youtube
# 2                   SET India  130400000.0    Youtube
# 3                   PewDiePie  111400000.0    Youtube
# 4                     MrBeast   92500000.0    Youtube
# 5           ✿ Kids Diana Show   92400000.0    Youtube
# 6                 Like Nastya   90100000.0    Youtube
# 7                         WWE   86900000.0    Youtube
# 8           Zee Music Company   82700000.0    Youtube
# 9               Vlad and Niki   80400000.0    Youtube

# %%
yt.rename(columns={'Followers': 'Youtube'}, inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/3272935213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yt.rename(columns={'Followers': 'Youtube'}, inplace=True)

# %%
yt.rename(columns={'channel name': 'user'}, inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/1437557193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yt.rename(columns={'channel name': 'user'}, inplace=True)

# %%
ig= pd.read_csv('./Datos/ig_limpio.csv', index_col=0)
ig.head()
# Out:
#   Influencer insta name instagram name            category   Followers  \
# 0                   433            433  Sports with a ball  48500000.0
# 1          __youngbae__        TAEYANG               Music  12700000.0
# 2           _agentgirl_  НАСТЯ ИВЛЕЕВА               Shows  18800000.0
# 3           _imyour_joy            Joy           Lifestyle  13500000.0
# 4         _jeongjaehyun        Jaehyun         Art/Artists  11100000.0
#
#     audience  authentic_engagement  engagement_avg red_social
# 0      Spain              383100.0        637000.0  Instagram
# 1  Indonesia              478000.0        542300.0  Instagram
# 2     Russia              310800.0        377900.0  Instagram
# 3  Indonesia             1100000.0       1400000.0  Instagram
# 4  Indonesia             2500000.0       3100000.0  Instagram

# %%
ig.sort_values(by='Followers', ascending=False, inplace=True)
ig.head()
# Out:
#     Influencer insta name     instagram name            category    Followers  \
# 388             instagram          Instagram         Photography  487200000.0
# 203             cristiano  Cristiano Ronaldo  Sports with a ball  419600000.0
# 510           kyliejenner       Kylie Jenner             Fashion  323300000.0
# 532              leomessi          Leo Messi  Sports with a ball  315400000.0
# 814           selenagomez       Selena Gomez               Music  308200000.0
#
#           audience  authentic_engagement  engagement_avg red_social
# 388          India              352300.0        467400.0  Instagram
# 203          India             5700000.0       7000000.0  Instagram
# 510  United States             7600000.0      12300000.0  Instagram
# 532      Argentina             4000000.0       5300000.0  Instagram
# 814  United States             3300000.0       4400000.0  Instagram

# %%
ig=ig[:10]
ig
# Out:
#     Influencer insta name     instagram name                   category  \
# 388             instagram          Instagram                Photography
# 203             cristiano  Cristiano Ronaldo         Sports with a ball
# 510           kyliejenner       Kylie Jenner                    Fashion
# 532              leomessi          Leo Messi         Sports with a ball
# 814           selenagomez       Selena Gomez                      Music
# 899               therock            therock  Cinema & Actors/actresses
# 87           arianagrande      Ariana Grande                      Music
# 494         kimkardashian     Kim Kardashian                    Fashion
# 126               beyonce           Beyoncé                      Music
# 489       khloekardashian  Khloé Kardashian         Clothing & Outfits
#
#        Followers       audience  authentic_engagement  engagement_avg  \
# 388  487200000.0          India              352300.0        467400.0
# ...

# %%
ig=ig[['instagram name', 'Followers', 'red_social']]
ig.reset_index()
# Out:
#    index     instagram name    Followers red_social
# 0    388          Instagram  487200000.0  Instagram
# 1    203  Cristiano Ronaldo  419600000.0  Instagram
# 2    510       Kylie Jenner  323300000.0  Instagram
# 3    532          Leo Messi  315400000.0  Instagram
# 4    814       Selena Gomez  308200000.0  Instagram
# 5    899            therock  307000000.0  Instagram
# 6     87      Ariana Grande  302300000.0  Instagram
# 7    494     Kim Kardashian  296400000.0  Instagram
# 8    126           Beyoncé  246900000.0  Instagram
# 9    489  Khloé Kardashian  230200000.0  Instagram

# %%
ig.rename(columns={'Followers': 'Instagram'},inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/982928240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ig.rename(columns={'Followers': 'Instagram'},inplace=True)

# %%
ig.rename(columns={'instagram name': 'user'}, inplace=True)
# Out:
# /var/folders/0b/r1tw2m0d04b5wkj6n99ypszr0000gn/T/ipykernel_2834/61929423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ig.rename(columns={'instagram name': 'user'}, inplace=True)

# %%
top_= pd.concat([tk, yt, ig])
top_
# Out:
#                            user       TikTok red_social      Youtube  \
# 3               charli d’amelio  135400000.0     TikTok          NaN
# 6                  Khabane lame  135200000.0     TikTok          NaN
# 31                 Bella Poarch   88500000.0     TikTok          NaN
# 27                  Addison Rae   87300000.0     TikTok          NaN
# 63                   Will Smith   67400000.0     TikTok          NaN
# 22              Kimberly Loaiza   61000000.0     TikTok          NaN
# 280                       dixie   57200000.0     TikTok          NaN
# 844                  Loren Gray   54300000.0     TikTok          NaN
# 25                      Dominik   50700000.0     TikTok          NaN
# 74                      Kris HC   43300000.0     TikTok          NaN
# 0                      T-Series          NaN    Youtube  212100000.0
# 1    Cocomelon - Nursery Rhymes          NaN    Youtube  132100000.0
# 2                     SET India          NaN    Youtube  130400000.0
# ...

# %%
top_.to_csv('./Datos/top.csv')
